# %%
import pandas as pd

# %%
dataset=pd.read_csv(r"C:\Users\Garv Khurana\OneDrive\Desktop\house prize data.csv")

# %% [markdown]
# just a quick overview of the data

# %%
dataset.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
dataset.tail()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished

# %%
dataset.shape
# Out:
# (545, 13)

# %%
dataset.duplicated().any()
# Out:
# False

# %%
dataset.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
dataset.isna().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
dataset["furnishingstatus"].unique()
# Out:
# array(['furnished', 'semi-furnished', 'unfurnished'], dtype=object)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
dataset.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %% [markdown]
# some EDA on  data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# here we can see the data is right skewed we have to transform into normal distribution by applying log transformation

# %%
sns.distplot(dataset["price"])
# Out:
# C:\Users\Garv Khurana\AppData\Local\Temp\ipykernel_21000\2425984916.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["price"])
# C:\Users\Garv Khurana\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
import numpy as np
dataset['price'] = np.log(dataset['price'])

# %%
dataset
# Out:
#          price  area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    16.403275  7420         4          2        3      yes        no
# 1    16.321036  8960         4          4        4      yes        no
# 2    16.321036  9960         3          2        2      yes        no
# 3    16.318175  7500         4          2        2      yes        no
# 4    16.250001  7420         4          1        2      yes       yes
# ..         ...   ...       ...        ...      ...      ...       ...
# 540  14.414347  3000         2          1        1      yes        no
# 541  14.384879  2400         3          1        1       no        no
# 542  14.375126  3620         2          1        1      yes        no
# 543  14.375126  2910         3          1        1       no        no
# 544  14.375126  3850         3          1        2      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
sns.distplot(dataset["price"])
# Out:
# C:\Users\Garv Khurana\AppData\Local\Temp\ipykernel_21000\2425984916.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["price"])
# C:\Users\Garv Khurana\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.pairplot(dataset)
plt.show()
# Out:
# C:\Users\Garv Khurana\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Garv Khurana\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Garv Khurana\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
plt.scatter(dataset["price"],dataset["area"],c=)

# %% [markdown]
# finding outliers in a the dataset or else we could opt for robust scaling afterwards

# %%
sns.boxplot(dataset)
# Out:
# C:\Users\Garv Khurana\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Garv Khurana\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Garv Khurana\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
Q1 = dataset["area"].quantile(0.25)
Q3 = dataset['area'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
lower_bound
# Out:
# -540.0

# %%
upper_bound
# Out:
# 10500.0

# %%
df = dataset[(dataset['area'] >= lower_bound) & (dataset['area'] <= upper_bound)]

# %%
df
# Out:
#          price  area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    16.403275  7420         4          2        3      yes        no
# 1    16.321036  8960         4          4        4      yes        no
# 2    16.321036  9960         3          2        2      yes        no
# 3    16.318175  7500         4          2        2      yes        no
# 4    16.250001  7420         4          1        2      yes       yes
# ..         ...   ...       ...        ...      ...      ...       ...
# 540  14.414347  3000         2          1        1      yes        no
# 541  14.384879  2400         3          1        1       no        no
# 542  14.375126  3620         2          1        1      yes        no
# 543  14.375126  2910         3          1        1       no        no
# 544  14.375126  3850         3          1        2      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
sns.boxplot(df)
# Out:
# C:\Users\Garv Khurana\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Garv Khurana\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Garv Khurana\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# here we have initilize the values of the dependant and the independant variables

# %%
x=df.drop(columns="price")
y=df["price"]

# %%
x=df.drop(columns="price")
y=df["price"]

# %% [markdown]
# now as we all know ML algos cant accept text data so we have to convert them into integer values therefore we have converted the independant varible into integer form

# %%
x=pd.get_dummies(x,drop_first=True).astype(int)

# %%
x
# Out:
#      area  bedrooms  bathrooms  stories  parking  mainroad_yes  guestroom_yes  \
# 0    7420         4          2        3        2             1              0
# 1    8960         4          4        4        3             1              0
# 2    9960         3          2        2        2             1              0
# 3    7500         4          2        2        3             1              0
# 4    7420         4          1        2        2             1              1
# ..    ...       ...        ...      ...      ...           ...            ...
# 540  3000         2          1        1        2             1              0
# 541  2400         3          1        1        0             0              0
# 542  3620         2          1        1        0             1              0
# 543  2910         3          1        1        0             0              0
# 544  3850         3          1        2        0             1              0
#
# ...

# %%
y
# Out:
# 0      16.403275
# 1      16.321036
# 2      16.321036
# 3      16.318175
# 4      16.250001
#          ...
# 540    14.414347
# 541    14.384879
# 542    14.375126
# 543    14.375126
# 544    14.375126
# Name: price, Length: 533, dtype: float64

# %% [markdown]
# now we will distribute the data between training data and testing data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
x_train.shape
# Out:
# (373, 13)

# %%
x_test.shape
# Out:
# (160, 13)

# %% [markdown]
# now we will scale the data in one standard form with the help of standard scaler

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x_train_final=ss.fit_transform(x_train)
x_test_final=ss.transform(x_test)

# %% [markdown]
# now we will start implementing our data in the algorithms

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_percentage_error,mean_absolute_error
lr=LinearRegression()
lr.fit(x_train_final,y_train)
prediction_of_lr=lr.predict(x_test_final)
mean_absolute_percentage_error(y_test,prediction_of_lr)
# Out:
# 0.011750748730462729

# %%
plt.scatter(y_test,prediction_of_lr)
sns.regplot(x=y_test,y=prediction_of_lr)
# Out:
# <Axes: xlabel='price'>

# %%
sns.regplot(x=y_test,y=prediction_of_knn)
# Out:
# <Axes: xlabel='price'>
